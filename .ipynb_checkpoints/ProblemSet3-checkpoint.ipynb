# %% [markdown]
# <h6>Student name: Thi Pham</h6>
# <h6>Student ID#: 200467699</h6>
#
# ## Problem Set 3

# %% [markdown]
# ### Question 1: Occupations

# %% [markdown]
# ##### Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### import the dataset & Assign it to a variable called users

# %%
users = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', '|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ##### Discover what is the mean age per occupation

# %%
users[["occupation","age"]].groupby("occupation").mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ##### Discover the Male ratio per occupation and sort it from the most to the least

# %%
tmp_df = users[["occupation","gender","user_id"]].groupby(["occupation", "gender"]).count()
tmp_df
# Out:
#                       user_id
# occupation    gender
# administrator F            36
#               M            43
# artist        F            13
#               M            15
# doctor        M             7
# educator      F            26
#               M            69
# engineer      F             2
#               M            65
# entertainment F             2
#               M            16
# executive     F             3
#               M            29
# healthcare    F            11
#               M             5
# homemaker     F             6
#               M             1
# lawyer        F             2
#               M            10
# librarian     F            29
#               M            22
# marketing     F            10
#               M            16
# none          F             4
#               M             5
# other         F            36
#               M            69
# programmer    F             6
#               M            60
# ...

# %%
p_table = pd.pivot_table(tmp_df,'user_id','occupation','gender').reindex()
p_table['M_ratio'] = p_table['M']/p_table['F']
p_table.sort_values(by=['M_ratio'], ascending=False)
# Out:
# gender            F      M    M_ratio
# occupation
# engineer        2.0   65.0  32.500000
# technician      1.0   26.0  26.000000
# retired         1.0   13.0  13.000000
# programmer      6.0   60.0  10.000000
# executive       3.0   29.0   9.666667
# scientist       3.0   28.0   9.333333
# entertainment   2.0   16.0   8.000000
# lawyer          2.0   10.0   5.000000
# salesman        3.0    9.0   3.000000
# educator       26.0   69.0   2.653846
# student        60.0  136.0   2.266667
# other          36.0   69.0   1.916667
# marketing      10.0   16.0   1.600000
# writer         19.0   26.0   1.368421
# none            4.0    5.0   1.250000
# administrator  36.0   43.0   1.194444
# artist         13.0   15.0   1.153846
# librarian      29.0   22.0   0.758621
# healthcare     11.0    5.0   0.454545
# homemaker       6.0    1.0   0.166667
# doctor          NaN    7.0        NaN

# %% [markdown]
# ##### For each occupation, calculate the minimum and maximum ages

# %%
users[["occupation","age"]].groupby("occupation").agg(['min', 'max'])
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# ##### For each combination of occupation and sex, calculate the mean age

# %%
tmp_df = users[["occupation","gender","age"]].groupby(["occupation", "gender"]).mean()
tmp_df
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# ##### For each occupation present the percentage of women and men

# %%
tmp_df = users[["occupation","gender","user_id"]].groupby(["occupation", "gender"]).count()
tmp_df
# Out:
#                       user_id
# occupation    gender
# administrator F            36
#               M            43
# artist        F            13
#               M            15
# doctor        M             7
# educator      F            26
#               M            69
# engineer      F             2
#               M            65
# entertainment F             2
#               M            16
# executive     F             3
#               M            29
# healthcare    F            11
#               M             5
# homemaker     F             6
#               M             1
# lawyer        F             2
#               M            10
# librarian     F            29
#               M            22
# marketing     F            10
#               M            16
# none          F             4
#               M             5
# other         F            36
#               M            69
# programmer    F             6
#               M            60
# ...

# %%
p_table = pd.pivot_table(tmp_df,'user_id','occupation','gender').reindex().fillna(0)
p_table['F_percentage'] = (p_table['F']/(p_table['F']+p_table['M']))*100
p_table['M_percentage'] = (p_table['M']/(p_table['F']+p_table['M']))*100
p_table
# Out:
# gender            F      M  F_percentage  M_percentage
# occupation
# administrator  36.0   43.0     45.569620     54.430380
# artist         13.0   15.0     46.428571     53.571429
# doctor          0.0    7.0      0.000000    100.000000
# educator       26.0   69.0     27.368421     72.631579
# engineer        2.0   65.0      2.985075     97.014925
# entertainment   2.0   16.0     11.111111     88.888889
# executive       3.0   29.0      9.375000     90.625000
# healthcare     11.0    5.0     68.750000     31.250000
# homemaker       6.0    1.0     85.714286     14.285714
# lawyer          2.0   10.0     16.666667     83.333333
# librarian      29.0   22.0     56.862745     43.137255
# marketing      10.0   16.0     38.461538     61.538462
# none            4.0    5.0     44.444444     55.555556
# other          36.0   69.0     34.285714     65.714286
# programmer      6.0   60.0      9.090909     90.909091
# retired         1.0   13.0      7.142857     92.857143
# ...

# %% [markdown]
# ### Question 2:

# %% [markdown]
# ##### Step 2 & 3: Import the dataset & Assign it to a variable called euro12

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_&_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.dtypes
# Out:
# Team                           object
# Goals                           int64
# Shots on target                 int64
# Shots off target                int64
# Shooting Accuracy              object
# % Goals-to-shots               object
# Total shots (inc. Blocked)      int64
# Hit Woodwork                    int64
# Penalty goals                   int64
# Penalties not scored            int64
# Headed goals                    int64
# Passes                          int64
# Passes completed                int64
# Passing Accuracy               object
# Touches                         int64
# Crosses                         int64
# Dribbles                        int64
# Corners Taken                   int64
# Tackles                         int64
# Clearances                      int64
# Interceptions                   int64
# Clearances off line           float64
# Clean Sheets                    int64
# Blocks                          int64
# Goals conceded                  int64
# ...

# %% [markdown]
# ##### Step 4 Select only the Goal column

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ##### Step 5 How many team participated in the Euro2012?

# %%
euro12['Team'].unique().size
# Out:
# 16

# %% [markdown]
# ##### Step 6 What is the number of columns in the dataset?

# %%
euro12.columns.size
# Out:
# 35

# %% [markdown]
# ##### Step 7 View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12.filter(["Team", "Yellow Cards", "Red Cards"], axis=1)
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ##### Step 8 Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=True)
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# ###### Step 9 Calculate the mean Yellow Cards given per Team

# %%
discipline['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# ###### Step 10 Filter teams that scored more than 6 goals

# %%
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# ###### Step 11 Select the teams that start with G

# %%
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# ###### Step 12 Select the first 7 columns

# %%
euro12.iloc[: , :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ###### Step 13 Select all columns except the last 3

# %%
euro12.iloc[: , :(euro12.columns.size - 3)]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])].filter(["Team", "Shooting Accuracy"], axis=1)
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ### Question 3:
